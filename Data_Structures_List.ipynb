# %% [markdown]
# ## List Samples
#
# * 1D - one diminsion
# * Heterogenous - allow mulityple data type
# * Accept duplicate values
# * Indexing and slicing is possible
# * Mutable - value can be changed in list , add, update, clear,
# * print items items left to right

# %%
empty_list=[]  #empty list

# %%
type(empty_list) #get data type
# Out:
# list

# %%
products = ["Laptop", "Mouse", "Keyboard"]
for product in products:
    print(product) #print list items
# Out:
# Laptop
# Mouse
# Keyboard

# %%
print(products[0]) # get data by index
# Out:
# Laptop

# %%
print(products[1:3]) # get data by slicing
# Out:
# ['Mouse', 'Keyboard']

# %%
products = ["Laptop", "Mouse", "Keyboard",1.3,1,22,9.0]
for product in products:
    print(product) #print list items by index from left to right
# Out:
# Laptop
# Mouse
# Keyboard
# 1.3
# 1
# 22
# 9.0

# %%
products[3]="Monitor"
for product in products:
    print(product) #print list items by index from left to right
# Out:
# Laptop
# Mouse
# Keyboard
# Monitor
# 1
# 22
# 9.0

# %% [markdown]
# ### Function in list

# %% [markdown]
# ##### append() Adds an element at the end of the list

# %%
products = ["Laptop", "Mouse", "Keyboard"]

products.append("Monitor")

for product in products:
    print(product) #print list items
# Out:
# Laptop
# Mouse
# Keyboard
# Monitor

# %%
sales = [1200, 1500, 1800, 2000]

total = 0

for amount in sales:
    total += amount

print("Total Sales:", total)
# Out:
# Total Sales: 6500

# %%
sales.append(3000)

# %%
total = 0

for amount in sales:
    total += amount

print("Total Sales:", total)
# Out:
# Total Sales: 9500

# %%
orders = ["ORD101", "ORD102", "ORD103"]
orders.append("ORD104")

for order in orders:
    print("Processing:", order)
# Out:
# Processing: ORD101
# Processing: ORD102
# Processing: ORD103
# Processing: ORD104

# %% [markdown]
# ##### clear()  - Removes all the elements from the list

# %%
orders.clear()
print("Processing:", orders)
# Out:
# Processing: []

# %% [markdown]
# ##### copy() - Returns a copy of the list

# %%
orders = ["ORD101", "ORD102", "ORD103"]
for order in orders:
    print("Processing:", order)
# Out:
# Processing: ORD101
# Processing: ORD102
# Processing: ORD103

# %%
final_orders = orders.copy() # copy orders list to final_orders 

for order in final_orders:
    print("Processing:",order)
# Out:
# Processing: ORD101
# Processing: ORD102
# Processing: ORD103

# %% [markdown]
# #####  count() - Returns the number of elements with the specified value

# %%
print(final_orders.count)
# Out:
# <built-in method count of list object at 0x000002BBB5D9A600>

# %%
print(final_orders.count)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [24], in <module>
# ----> 1 print(final_orders.count())
#
# TypeError: list.count() takes exactly one argument (0 given)

# %%
print(final_orders.count("ORD103"))
# Out:
# 1

# %%
final_orders.append("ORD103")

# %%
print(final_orders.count("ORD103"))  # returns how many time particular item count
# Out:
# 2

# %% [markdown]
# ##### extend() - Adds multiple items to the end of the list.

# %%
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD103']

# %%
final_orders.extend('ORD104','ORD105') #error
final_orders
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <module>
# ----> 1 final_orders.extend('ORD104','ORD105')
#       2 final_orders
#
# TypeError: list.extend() takes exactly one argument (2 given)

# %%
final_orders.extend(['ORD104','ORD105']) # add as list
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD103', 'ORD104', 'ORD105']

# %% [markdown]
# ##### insert() - Inserts an item at a specified position.

# %%
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD103', 'ORD104', 'ORD105']

# %%
final_orders.insert(1,'ORD102_d')
final_orders
# Out:
# ['ORD101', 'ORD102_d', 'ORD102', 'ORD103', 'ORD103', 'ORD104', 'ORD105']

# %% [markdown]
# ##### remove() Removes the first matching item.

# %%
final_orders
# Out:
# ['ORD101', 'ORD102_d', 'ORD102', 'ORD103', 'ORD103', 'ORD104', 'ORD105']

# %%
final_orders.remove('ORD102_d') 
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD103', 'ORD104', 'ORD105']

# %% [markdown]
# #####  pop() - Removes an item by index and returns it.

# %%
final_orders
final_orders.pop(2)
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD104', 'ORD105']

# %% [markdown]
# ##### index() Returns the index of the first matching item.

# %%
final_orders.index('ORD103')
# Out:
# 2

# %% [markdown]
# #####  sort() - Sorts the list in ascending order.

# %%
final_orders.sort()
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD104', 'ORD105']

# %%
final_orders.insert(1,'ORD106')
final_orders
# Out:
# ['ORD101', 'ORD106', 'ORD102', 'ORD103', 'ORD104', 'ORD105']

# %%
final_orders.sort()
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD104', 'ORD105', 'ORD106']

# %% [markdown]
# ##### sort(reverse=True) Sorts in descending order.

# %%
final_orders.sort(reverse=True)
final_orders
# Out:
# ['ORD106', 'ORD105', 'ORD104', 'ORD103', 'ORD102', 'ORD101']

# %% [markdown]
# ##### reverse() Reverses the order of the list.

# %%
final_orders.sort()
final_orders
# Out:
# ['ORD101', 'ORD102', 'ORD103', 'ORD104', 'ORD105', 'ORD106']

# %%
final_orders.reverse()
final_orders
# Out:
# ['ORD106', 'ORD105', 'ORD104', 'ORD103', 'ORD102', 'ORD101']

# %% [markdown]
# ##### len() Returns the number of items in a list.

# %%
final_orders
# Out:
# ['ORD106', 'ORD105', 'ORD104', 'ORD103', 'ORD102', 'ORD101']

# %%
len(final_orders)
# Out:
# 6

# %% [markdown]
# ##### min() Returns the smallest value.

# %%
marks = [80, 65, 90, 75]

print(min(marks))
# Out:
# 65

# %% [markdown]
# ##### max() Returns the largest value

# %%
marks = [80, 65, 90, 75]

print(max(marks))
# Out:
# 90

# %% [markdown]
# ##### sum() Returns the total of all numeric values.

# %%
sales = [1200, 1500, 1800]

print(sum(sales))
# Out:
# 4500

# %% [markdown]
# ##### sorted() Returns a new sorted list without changing the original.

# %%
numbers = [30, 10, 20]

new_list = sorted(numbers)

print(new_list)
print(numbers)
# Out:
# [10, 20, 30]
# [30, 10, 20]

# %% [markdown]
# ## Sets
#
# * 1D - one diminsion
# * Heterogenous - allow mulityple data type
# * It won't allow duplicate values
# * Indexing and slicing is not possible
# * Mutable - value can be changed in list , add, update, clear,

# %%
set_empty_cart=set()
type(set_empty_cart)
# Out:
# set

# %%
numbers = {10, 20, 30, 20}
print(numbers) #remove duplicate values
# Out:
# {10, 20, 30}

# %%
products = {"Laptop", "Mouse", "Keyboard"}
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse'}

# %%
products = {"Laptop", "Mouse", "Keyboard","Mouse"}
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse'}

# %%
products = {"Laptop", "Mouse", "Keyboard","Mouse",2,33.3}
products  # Heterogenous - allow mulityple data type
# Out:
# {2, 33.3, 'Keyboard', 'Laptop', 'Mouse'}

# %% [markdown]
# ##### remove() Removes an element. Raises an error if it doesn't exist.

# %%
products.remove(2)
products
# Out:
# {33.3, 'Keyboard', 'Laptop', 'Mouse'}

# %%
products.remove(33.3)
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse'}

# %% [markdown]
# ##### add() Adds a single element to a set.

# %%
products.add("Monitor")
products
# Out:
# {'Keyboard', 'Laptop', 'Monitor', 'Mouse'}

# %% [markdown]
# ##### update() Adds multiple elements from another collection.

# %%
products.update(["Note Pad","Pen"])
products # add add from list to set
# Out:
# {'Keyboard', 'Laptop', 'Monitor', 'Mouse', 'Note Pad', 'Pen'}

# %% [markdown]
# ##### discard()  - Removes an element if it exists. Does not raise an error if it doesn't.

# %%
products.discard("pen") #lower case not matched

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Monitor', 'Mouse', 'Note Pad', 'Pen'}

# %%
products.discard("Pen")
products
# Out:
# {'Keyboard', 'Laptop', 'Monitor', 'Mouse', 'Note Pad'}

# %% [markdown]
# ##### pop() Removes and returns a random element.

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Monitor', 'Mouse', 'Note Pad'}

# %%
item = products.pop()

# %%
item
# Out:
# 'Monitor'

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %% [markdown]
# ##### copy() Creates a copy of a set.

# %%
set1 = {10, 20, 30}

set2 = set1.copy()

print(set2)
# Out:
# {10, 20, 30}

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit = products.copy()

# %%
final_products_lsit
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %% [markdown]
# ##### union() Returns all unique elements from both sets.

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}

print(set1.union(set2))
# Out:
# {1, 2, 3, 4, 5}

# %%
final_products_lsit.update(['Book','File','Mouse Pad']) # add few more items

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.union(final_products_lsit)) # union - function
# Out:
# {'Note Pad', 'File', 'Mouse', 'Mouse Pad', 'Keyboard', 'Book', 'Laptop'}

# %% [markdown]
# ##### intersection() Returns common elements.

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}

print(set1.intersection(set2))
# Out:
# {2, 3}

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.intersection(final_products_lsit))
# Out:
# {'Mouse', 'Keyboard', 'Laptop', 'Note Pad'}

# %% [markdown]
# ##### difference() Returns elements present only in the first set.

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}

print(set1.difference(set2))
# Out:
# {1}

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.difference(final_products_lsit))
# Out:
# set()

# %%
print(final_products_lsit.difference(products))
# Out:
# {'Book', 'File', 'Mouse Pad'}

# %% [markdown]
# ##### symmetric_difference() Returns elements that are in either set, but not both.

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}

print(set1.symmetric_difference(set2))
# Out:
# {1, 4}

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.symmetric_difference(final_products_lsit))
# Out:
# {'Book', 'Mouse Pad', 'File'}

# %% [markdown]
# ##### issubset() Checks whether one set is a subset of another.

# %%
set1 = {1, 2}
set2 = {1, 2, 3, 4}

print(set1.issubset(set2))
# Out:
# True

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.issubset(final_products_lsit))
# Out:
# True

# %%
print(final_products_lsit.issubset(products))
# Out:
# False

# %% [markdown]
# ##### issuperset() Checks whether one set contains another.

# %%
set1 = {1, 2, 3, 4}
set2 = {1, 2}

print(set1.issuperset(set2))
# Out:
# True

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.issuperset(final_products_lsit))
# Out:
# False

# %%
print(final_products_lsit.issuperset(products))
# Out:
# True

# %% [markdown]
# ##### isdisjoint() Checks whether two sets have no common elements.

# %%
products
# Out:
# {'Keyboard', 'Laptop', 'Mouse', 'Note Pad'}

# %%
final_products_lsit
# Out:
# {'Book', 'File', 'Keyboard', 'Laptop', 'Mouse', 'Mouse Pad', 'Note Pad'}

# %%
print(products.isdisjoint(final_products_lsit))
# Out:
# False

# %%
print(final_products_lsit.isdisjoint(products))
# Out:
# False

# %%
set1 = {1, 2}
set2 = {3, 4}

print(set1.isdisjoint(set2))
# Out:
# True

# %% [markdown]
# ##### intersection_update Updates the set with only common elements.

# %%
set1 = {1, 2, 3}
set2 = {2, 3, 4}

set1.intersection_update(set2)

print(set1)
# Out:
# {2, 3}

# %%
set1
# Out:
# {2, 3}

# %%
set2
# Out:
# {2, 3, 4}

# %% [markdown]
# ##### difference_update() Removes common elements from the first set.

# %%
set1 = {1, 2, 3}
set2 = {2, 3}

# %%
set1
# Out:
# {1, 2, 3}

# %%
set2
# Out:
# {2, 3}

# %%
set1.difference_update(set2)

print(set1)
# Out:
# {1}

# %%
set1
# Out:
# {1}

# %%
set2
# Out:
# {2, 3}

# %% [markdown]
# ##### symmetric_difference_update() Updates the set with elements that are unique to each set.

# %%
set1 = {1, 2, 3}
set2 = {3, 4, 5}

# %%
set1
# Out:
# {1, 2, 3}

# %%
set2
# Out:
# {3, 4, 5}

# %%
set1.symmetric_difference_update(set2)

# %%
set1
# Out:
# {1, 2, 4, 5}

# %%
set2
# Out:
# {3, 4, 5}

# %% [markdown]
# ## Tuple ()
#
# * 1D - one diminsion
# * Heterogenous - allow mulityple data type
# * Accept duplicate values
# * Indexing and slicing is possible
# * Immutable - value can be changed in list

# %%
empty_cart_3 = ()
type(empty_cart_3)
# Out:
# tuple

# %%
products_tuple = ("Laptop", "Mouse", "Keyboard","Mouse")
products_tuple
# Out:
# ('Laptop', 'Mouse', 'Keyboard', 'Mouse')

# %% [markdown]
# #####  count() - Counts how many times an element appears.

# %%
products_tuple
# Out:
# ('Laptop', 'Mouse', 'Keyboard', 'Mouse')

# %%
print(products_tuple.count("Mouse"))
# Out:
# 2

# %% [markdown]
# ##### index() Returns the index of the first occurrence.

# %%
products_tuple
# Out:
# ('Laptop', 'Mouse', 'Keyboard', 'Mouse')

# %%
print(products_tuple.index("Mouse"))
# Out:
# 1

# %% [markdown]
# ##### len() (Built-in Function) - Returns the number of elements.

# %%
products_tuple
# Out:
# ('Laptop', 'Mouse', 'Keyboard', 'Mouse')

# %%
print(len(products_tuple))
# Out:
# 4

# %% [markdown]
# ##### max() (Built-in Function)

# %%
numbers = (10, 50, 30, 20)

print(max(numbers))
# Out:
# 50

# %% [markdown]
# ##### min() (Built-in Function)

# %%
numbers = (10, 50, 30, 20)

print(min(numbers))
# Out:
# 10

# %% [markdown]
# ##### sum() (Built-in Function)

# %%
sales = (1200, 1500, 1800)

print(sum(sales))
# Out:
# 4500

# %% [markdown]
# ##### sorted() (Built-in Function)

# %%
numbers = (40, 10, 30, 20)

print(sorted(numbers))
# Out:
# [10, 20, 30, 40]

# %% [markdown]
# ##### Tuple Concatenation (+)  Joins two tuples.

# %%
tuple1 = (1, 2, 3)
tuple2 = (4, 5)

result = tuple1 + tuple2

print(result)
# Out:
# (1, 2, 3, 4, 5)

# %% [markdown]
# ##### Tuple Repetition (*) Repeats a tuple.

# %%
days = ("Mon",)

print(days * 3)
# Out:
# ('Mon', 'Mon', 'Mon')

# %% [markdown]
# ##### Membership Operators (in, not in)  Check whether an item exists.

# %%
fruits = ("Apple", "Banana", "Mango")

print("Apple" in fruits)
print("Orange" not in fruits)
# Out:
# True
# True

# %% [markdown]
# ##### Tuple Slicing Extract part of a tuple.

# %%
numbers = (10, 20, 30, 40, 50)

print(numbers[1:4])
# Out:
# (20, 30, 40)

# %% [markdown]
# ##### Tuple Unpacking

# %%
employee = ("Deepak", "IT", 55000)

name, department, salary = employee

print(name)
print(department)
print(salary)
# Out:
# Deepak
# IT
# 55000

# %% [markdown]
# ##### Iterate Through a Tuple

# %%
colors = ("Red", "Green", "Blue")

for color in colors:
    print(color)
# Out:
# Red
# Green
# Blue

# %% [markdown]
# ##### Convert Tuple to List

# %%
numbers = (10, 20, 30)

numbers_list = list(numbers)

print(numbers_list)
# Out:
# [10, 20, 30]

# %% [markdown]
# ##### Convert List to Tuple

# %%
numbers = [10, 20, 30]

numbers_tuple = tuple(numbers)

print(numbers_tuple)
# Out:
# (10, 20, 30)

# %% [markdown]
# #####  Dictionary - { }
#
# * 2D
# * Heterogenous
# * Mutable
# * Indexing and Slicing is not possible

# %%
empty_cart_4 ={}
type(empty_cart_4)
# Out:
# dict

# %%
employee = {
    "EmployeeId": 101,
    "EmployeeName": "Deepak",
    "Department": "IT",
    "Salary": 55000,
    "City": "Bangalore"
}

print(employee)
# Out:
# {'EmployeeId': 101, 'EmployeeName': 'Deepak', 'Department': 'IT', 'Salary': 55000, 'City': 'Bangalore'}

# %%
print(employee["EmployeeId"])
# Out:
# 101

# %%
employee["Salary"] = 65000
print(employee)
# Out:
# {'EmployeeId': 101, 'EmployeeName': 'Deepak', 'Department': 'IT', 'Salary': 65000, 'City': 'Bangalore'}

# %%
employee["State"] = "Karnataka"
print(employee)
# Out:
# {'EmployeeId': 101, 'EmployeeName': 'Deepak', 'Department': 'IT', 'Salary': 65000, 'City': 'Bangalore', 'State': 'Karnataka'}

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Department': 'IT',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
del employee["Department"]
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %% [markdown]
# #### Dictionary Methods

# %% [markdown]
# ##### get() Returns the value of a key safely.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
print(employee.get("Salary"))
# Out:
# 65000

# %% [markdown]
# ##### keys() Returns all keys.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
print(employee.keys())
# Out:
# dict_keys(['EmployeeId', 'EmployeeName', 'Salary', 'City', 'State'])

# %% [markdown]
# ##### values() Returns all values.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
print(employee.values())
# Out:
# dict_values([101, 'Deepak', 65000, 'Bangalore', 'Karnataka'])

# %% [markdown]
# ##### items() Returns key-value pairs.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
print(employee.items())
# Out:
# dict_items([('EmployeeId', 101), ('EmployeeName', 'Deepak'), ('Salary', 65000), ('City', 'Bangalore'), ('State', 'Karnataka')])

# %% [markdown]
# ##### update() Updates existing values or adds new ones.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 65000,
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
employee.update({"Department": "IT", "Salary": 55000})

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 55000,
#  'City': 'Bangalore',
#  'State': 'Karnataka',
#  'Department': 'IT'}

# %% [markdown]
# ##### pop() Removes a key and returns its value.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'Salary': 55000,
#  'City': 'Bangalore',
#  'State': 'Karnataka',
#  'Department': 'IT'}

# %%
salary = employee.pop("Salary")
print(salary)
print(employee)
# Out:
# 55000
# {'EmployeeId': 101, 'EmployeeName': 'Deepak', 'City': 'Bangalore', 'State': 'Karnataka', 'Department': 'IT'}

# %% [markdown]
# ##### popitem() Removes the last inserted key-value pair.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'City': 'Bangalore',
#  'State': 'Karnataka',
#  'Department': 'IT'}

# %%
employee.popitem()

print(employee)
# Out:
# {'EmployeeId': 101, 'EmployeeName': 'Deepak', 'City': 'Bangalore', 'State': 'Karnataka'}

# %% [markdown]
# ##### copy() Creates a copy of the dictionary.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
employee_new = employee.copy()
employee_new
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %% [markdown]
# ##### setdefault() Returns the value if the key exists; otherwise inserts the key with a default value.

# %%
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'City': 'Bangalore',
#  'State': 'Karnataka'}

# %%
employee.setdefault("Department", "IT")
employee
# Out:
# {'EmployeeId': 101,
#  'EmployeeName': 'Deepak',
#  'City': 'Bangalore',
#  'State': 'Karnataka',
#  'Department': 'IT'}

# %% [markdown]
# ##### fromkeys() Creates a new dictionary from a list of keys.

# %%
keys = ["Name", "Department", "Salary"]

employee = dict.fromkeys(keys, "Not Available")

print(employee)
# Out:
# {'Name': 'Not Available', 'Department': 'Not Available', 'Salary': 'Not Available'}

# %% [markdown]
# #### Loop Through Dictionary

# %%
employee = {
    "Name": "Deepak",
    "Department": "IT"
}

for key in employee:
    print(key)
# Out:
# Name
# Department

# %%
for value in employee.values():
    print(value)
# Out:
# Deepak
# IT

# %%
for key, value in employee.items():
    print(key, ":", value)
# Out:
# Name : Deepak
# Department : IT

# %% [markdown]
# ##### Pandas

# %%
import pandas as pd

# %%
employee_details = {
    "Employee Id" : ["EMP001","EMP002","EMP003","EMP004","EMP005"],
    "Employee Name" : ["Deepak","Rajendran","Ravi","Priya","Darshan"],
    "Department" : ["IT","HR","HR","IT","IT"],
    "Salary" : ["45000","6000","52000","4000","3000"],
    "City" : ["Bangalore","Chennai","Bangalore","Bangalore","Chennai"],
    }
employee_details
# Out:
# {'Employee Id': ['EMP001', 'EMP002', 'EMP003', 'EMP004', 'EMP005'],
#  'Employee Name': ['Deepak', 'Rajendran', 'Ravi', 'Priya', 'Darshan'],
#  'Department': ['IT', 'HR', 'HR', 'IT', 'IT'],
#  'Salary': ['45000', '6000', '52000', '4000', '3000'],
#  'City': ['Bangalore', 'Chennai', 'Bangalore', 'Bangalore', 'Chennai']}

# %%
pd.DataFrame(data=employee_details)
# Out:
#   Employee Id Employee Name Department Salary       City
# 0      EMP001        Deepak         IT  45000  Bangalore
# 1      EMP002     Rajendran         HR   6000    Chennai
# 2      EMP003          Ravi         HR  52000  Bangalore
# 3      EMP004         Priya         IT   4000  Bangalore
# 4      EMP005       Darshan         IT   3000    Chennai

# %%
product_details = {
    "Product Id": ["P101", "P102", "P103", "P104"],
    "Product Name": ["Laptop", "Mouse", "Keyboard", "Monitor"],
    "Price": [55000, 800, 1200, 10000],
    "Stock": [15, 120, 80, 25],
    "Brand": ["Dell", "Logitech", "HP", "Samsung"]
}

print(product_details)
# Out:
# {'Product Id': ['P101', 'P102', 'P103', 'P104'], 'Product Name': ['Laptop', 'Mouse', 'Keyboard', 'Monitor'], 'Price': [55000, 800, 1200, 10000], 'Stock': [15, 120, 80, 25], 'Brand': ['Dell', 'Logitech', 'HP', 'Samsung']}

# %%
pd.DataFrame(data=product_details)
# Out:
#   Product Id Product Name  Price  Stock     Brand
# 0       P101       Laptop  55000     15      Dell
# 1       P102        Mouse    800    120  Logitech
# 2       P103     Keyboard   1200     80        HP
# 3       P104      Monitor  10000     25   Samsung

# %%
customer_details = {
    "Customer Id": ["C001", "C002", "C003"],
    "Customer Name": ["Arun", "Meena", "Vijay"],
    "City": ["Bangalore", "Chennai", "Hyderabad"],
    "Phone": ["9876543210", "9876500000", "9999911111"],
    "Email": ["arun@gmail.com", "meena@gmail.com", "vijay@gmail.com"]
}

print(customer_details)
# Out:
# {'Customer Id': ['C001', 'C002', 'C003'], 'Customer Name': ['Arun', 'Meena', 'Vijay'], 'City': ['Bangalore', 'Chennai', 'Hyderabad'], 'Phone': ['9876543210', '9876500000', '9999911111'], 'Email': ['arun@gmail.com', 'meena@gmail.com', 'vijay@gmail.com']}

# %%
pd.DataFrame(data=customer_details)
# Out:
#   Customer Id Customer Name       City       Phone            Email
# 0        C001          Arun  Bangalore  9876543210   arun@gmail.com
# 1        C002         Meena    Chennai  9876500000  meena@gmail.com
# 2        C003         Vijay  Hyderabad  9999911111  vijay@gmail.com

# %%
vehicle_details = {
    "Vehicle No": ["KA01AB1234", "TN10XY5678", "AP09CD7890"],
    "Driver": ["Ravi", "Kumar", "Suresh"],
    "Route": ["Bangalore-Chennai", "Chennai-Hyderabad", "Mumbai-Pune"],
    "Status": ["Running", "Loading", "Delivered"]
}

print(vehicle_details)
# Out:
# {'Vehicle No': ['KA01AB1234', 'TN10XY5678', 'AP09CD7890'], 'Driver': ['Ravi', 'Kumar', 'Suresh'], 'Route': ['Bangalore-Chennai', 'Chennai-Hyderabad', 'Mumbai-Pune'], 'Status': ['Running', 'Loading', 'Delivered']}

# %%
pd.DataFrame(data=customer_details)
# Out:
#   Customer Id Customer Name       City       Phone            Email
# 0        C001          Arun  Bangalore  9876543210   arun@gmail.com
# 1        C002         Meena    Chennai  9876500000  meena@gmail.com
# 2        C003         Vijay  Hyderabad  9999911111  vijay@gmail.com
